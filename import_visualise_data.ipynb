# %% [markdown]
# ## Importing Data From Yahoo Finance

# %% [raw]
# pip install --upgrade yfinance

# %%
import yfinance as yf
data = yf.download('AAPL', start="2024-01-01", end="2024-03-30")
data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
#
#               Volume
# Date
# 2024-01-02  82488700
# 2024-01-03  58414500
# 2024-01-04  71983600
# 2024-01-05  62303300
# 2024-01-08  59144500

# %% [markdown]
# ## Import as CSV

# %%
import pandas as pd
import numpy as np

infy = pd.read_csv('./python_for_trading_basics/data_modules/infy_data.csv')

# %%
infy # display dataframe
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ  28-Mar-2016     1207.80     1232.40     1237.00    1195.75
# 1     INFY     EQ  29-Mar-2016     1204.90     1199.00     1218.90    1191.55
# 2     INFY     EQ  30-Mar-2016     1197.25     1197.60     1210.00    1195.55
# 3     INFY     EQ  31-Mar-2016     1205.95     1210.25     1229.90    1200.30
# 4     INFY     BL  01-Apr-2016     2136.10     1220.25     1220.25    1220.15
# ..     ...    ...          ...         ...         ...         ...        ...
# 492   INFY     EQ  20-Mar-2018     1146.75     1148.60     1170.00    1148.60
# 493   INFY     EQ  21-Mar-2018     1164.55     1170.00     1175.50    1162.20
# 494   INFY     EQ  22-Mar-2018     1167.50     1164.50     1177.45    1155.30
# 495   INFY     EQ  23-Mar-2018     1161.30     1147.00     1173.80    1142.35
# 496   INFY     EQ  26-Mar-2018     1167.60     1166.90     1166.90    1144.00
#
# ...

# %%
infy.head() # first 5 rows
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  28-Mar-2016     1207.80     1232.40     1237.00    1195.75
# 1   INFY     EQ  29-Mar-2016     1204.90     1199.00     1218.90    1191.55
# 2   INFY     EQ  30-Mar-2016     1197.25     1197.60     1210.00    1195.55
# 3   INFY     EQ  31-Mar-2016     1205.95     1210.25     1229.90    1200.30
# 4   INFY     BL  01-Apr-2016     2136.10     1220.25     1220.25    1220.15
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     1209.00      1204.90        1212.25                5393755
# 1     1195.00      1197.25        1205.49                3497678
# 2     1206.60      1205.95        1205.03                2878409
# 3     1220.00      1218.30        1215.31                8998160
# 4     1220.15      1220.15        1220.18                 775000
#
#        Turnover  No. of Trades
# 0  6.538592e+09         112913
# 1  4.216417e+09          91763
# ...

# %%
infy.tail() # last 5 rows
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 492   INFY     EQ  20-Mar-2018     1146.75      1148.6     1170.00    1148.60
# 493   INFY     EQ  21-Mar-2018     1164.55      1170.0     1175.50    1162.20
# 494   INFY     EQ  22-Mar-2018     1167.50      1164.5     1177.45    1155.30
# 495   INFY     EQ  23-Mar-2018     1161.30      1147.0     1173.80    1142.35
# 496   INFY     EQ  26-Mar-2018     1167.60      1166.9     1166.90    1144.00
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 492     1164.55      1164.55        1159.74                4276883
# 493     1166.20      1167.50        1171.53                3846497
# 494     1156.00      1161.30        1167.57                3406584
# 495     1165.00      1167.60        1164.59                6004042
# 496     1155.60      1155.25        1153.17                4465361
#
#          Turnover  No. of Trades
# 492  4.960077e+09         111232
# ...

# %% [markdown]
# ## Matplotlib

# %%
import pandas as pd

infy = pd.read_csv('./python_for_trading_basics/data_modules/infy_dv.csv')

infy.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ  12-Mar-18     1163.40      1176.0     1191.85    1171.75
# 1   INFY     EQ  13-Mar-18     1185.75      1180.2     1197.00    1175.15
# 2   INFY     EQ  14-Mar-18     1183.80      1180.0     1190.60    1169.10
# 3   INFY     EQ  15-Mar-18     1180.80      1180.0     1188.40    1172.00
# 4   INFY     EQ  16-Mar-18     1182.50      1182.0     1182.40    1169.25
#
#    Last Price  Close Price  Average Price  Total Traded Quantity     Turnover  \
# 0      1184.0      1185.75        1186.26                3838485   4553456409
# 1      1182.0      1183.80        1187.19                4290526   5093652781
# 2      1181.1      1180.80        1180.26                2214855   2614111790
# 3      1181.9      1182.50        1180.88                3050750   3602569982
# 4      1170.0      1171.90        1172.96                8977413  10530177258
#
#    No. of Trades
# 0          82530
# ...

# %%
# Visualise Data
infy_close = infy[['Date', 'Close Price']] # required columns
infy_close.set_index('Date', inplace=True) # set index as date

infy_close
# Out:
#            Close Price
# Date
# 12-Mar-18      1185.75
# 13-Mar-18      1183.80
# 14-Mar-18      1180.80
# 15-Mar-18      1182.50
# 16-Mar-18      1171.90
# 19-Mar-18      1146.75
# 20-Mar-18      1164.55
# 21-Mar-18      1167.50
# 22-Mar-18      1161.30
# 23-Mar-18      1167.60
# 26-Mar-18      1155.25

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# This customizes the size of the plot as per the inputs. Here 14,5 represents the breadth and length of the plot.
plt.figure(figsize=(14, 5))

# This helps in plotting the blue color of the ‘infy_close’ series line graph.
plt.plot(infy_close, 'b')
# plt.plot (infy_close, 'g') # to plot green color

# This helps in plotting the discrete red data points of the closing prices of ‘infy_close’ series.
plt.plot(infy_close, 'ro')
# Here ‘r’ stands for ‘red’ and ‘o’ stands for circles while plotting our discrete data points.
# That is why the points are colored red and the default line color is blue.

# This gives a grid layout to the plot.
plt.grid(True)

# This gives the title to the plot.
plt.title('Infosys Close Price Representation')

# This labels the x-axis
plt.xlabel('Trading Days')

# This labels the y-axis
plt.ylabel('Infosys Close Price')


# To plot and visualise the data
plt.show()

# %% [markdown]
# ### Plot with labelled datasets

# %%
# Preparing data

import pandas as pd

infy2 = pd.read_csv('./python_for_trading_basics/data_modules/infy_dv.csv')

#infy2 = pd.read_csv ('C:/Users/academy/Desktop/infy_dv.csv')

infy2 = infy2[['Date', 'Close Price', 'Open Price']]  # Choosing more columns

infy2.set_index('Date', inplace=True)  # Setting 'Date' column as an index

infy2
# Out:
#            Close Price  Open Price
# Date
# 12-Mar-18      1185.75      1176.0
# 13-Mar-18      1183.80      1180.2
# 14-Mar-18      1180.80      1180.0
# 15-Mar-18      1182.50      1180.0
# 16-Mar-18      1171.90      1182.0
# 19-Mar-18      1146.75      1164.0
# 20-Mar-18      1164.55      1148.6
# 21-Mar-18      1167.50      1170.0
# 22-Mar-18      1161.30      1164.5
# 23-Mar-18      1167.60      1147.0
# 26-Mar-18      1155.25      1166.9

# %% [markdown]
# To plot better, use the plt.legend() function. This accepts different locality parameters where 0 stands for the best location of the legend, in the sense that little data is hidden by the legend.

# %%
# PLotting data

plt.figure(figsize=(14, 5))

plt.plot(infy2["Close Price"], lw=1.5, label='Close Price')
plt.plot(infy2["Open Price"], lw=1.5, label='Open Price')

plt.plot(infy2, 'ro')

plt.grid(True)

plt.legend(loc=0)

# This helps tighten the figure margins
plt.axis('tight')

plt.xlabel('Time')
plt.ylabel('Index')
plt.title('Representative plot with two datasets')

plt.show()

# %% [markdown]
# ### Scatter Plots
#
# In a scatter plot, the values of one data serve as the x values for the other data set. Such plots are usually used while plotting financial time series. Matplotlib provides a specific function to generate scatter plots known as the plt.scatter() function.

# %%
import numpy as np

y = np.random.standard_normal((100, 2))  # Random data created

plt.figure(figsize=(7, 5))

# The function 'scatter' is called to our 'plt' object
plt.scatter(y[:, 0], y[:, 1], marker='o')

plt.grid(True)
plt.xlabel('1st dataset')
plt.ylabel('2nd dataset')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ### Histogram Plots
#
# Histograms are often used in the context of financial returns. The code puts the frequency value of two datasets next to each other in the same plot. Use the plt.hist() function to plot the diagram.

# %%
# Random data created

np.random.seed(100)
y = np.random.standard_normal(size=1000)

plt.figure(figsize=(10, 5))

# The function 'hist' is called to our 'plt' object
plt.hist(y, label=['Returns Distribution'])

plt.grid(True)
plt.legend(loc=0)
plt.ylabel('Frequency')
plt.xlabel('Returns in Percentage')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ## Bollinger Band Function

# %%
def Bollinger_Bands(data, n):
    # calculate moving average
    MA = data['Close'].rolling(window=n).mean()
    # calculate standard deviation
    SD = data['Close'].rolling(window=n).std()

    data['Lower_BB'] = MA - (2 * SD)  # Lower Bollinger Band
    data['Upper_BB'] = MA + (2 * SD)  # Upper Bollinger Band

    return data

# %%
# load and view Nifty data
import pandas as pd
nifty = pd.read_csv('./python_for_trading_basics/data_modules/nifty_data.csv')
nifty.head()
# Out:
#           Date     Open     High      Low    Close    Shares Traded  \
# 0  18-Apr-2017  9163.00  9217.90  9095.45  9105.15        179569574
# 1  19-Apr-2017  9112.20  9120.50  9075.15  9103.50        179117382
# 2  20-Apr-2017  9108.10  9143.90  9102.65  9136.40        175629897
# 3  21-Apr-2017  9179.10  9183.65  9088.75  9119.40        159981265
# 4  24-Apr-2017  9135.35  9225.40  9130.55  9217.95        172908048
#
#   Turnover (Rs. Cr)
# 0           8527.50
# 1           8950.27
# 2           8843.50
# 3           8476.63
# 4           9720.75

# %%
# Calling Bollinger Bands for 'Nifty' index price data

n = 21  # window of the moving average as 21 days

# Calling the Bollinger Bands function
nifty_bb = Bollinger_Bands(nifty, n)

nifty_bb.tail()
# Out:
#             Date      Open      High       Low     Close    Shares Traded  \
# 244  11-Apr-2018  10428.15  10428.15  10355.60  10417.15        258077363
# 245  12-Apr-2018  10410.65  10469.90  10395.25  10458.65        246027888
# 246  13-Apr-2018  10495.30  10519.90  10451.45  10480.60        219724716
# 247  16-Apr-2018  10398.30  10540.15  10396.35  10528.35        200950876
# 248  17-Apr-2018  10557.30  10560.45  10495.65  10548.70        212449535
#
#     Turnover (Rs. Cr)     Lower_BB      Upper_BB
# 244          11790.58  9975.737576  10516.671948
# 245          12249.66  9972.248258  10523.708885
# 246          12354.55  9966.948182  10534.128009
# 247          11242.05  9955.158253  10557.103651
# 248          10501.71  9940.761993  10589.457054

# %%
# Plotting the Bollinger Bands for "Nifty' index
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10, 5))

plt.plot(nifty_bb.Close)
plt.plot(nifty_bb.Lower_BB)
plt.plot(nifty_bb.Upper_BB)
plt.grid(True)

plt.show()
